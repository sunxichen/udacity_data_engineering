# %%
import os
import glob
import psycopg2
import pandas as pd
import numpy as np
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")

# %%
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # 处理 `song_data`
#
# 进行ETL操作，即从文件中读取数据，存入数据表

# %%
song_files = get_files("data/song_data")

# %%
filepath = song_files[0] #暂时只ETL第一个文件
print(filepath)
# Out:
# /home/sunxichen/PycharmProjects/Data_Engineering/Data Modeling/Project1/data/song_data/A/A/A/TRAAAEF128F4273421.json

# %%
df = pd.read_json(filepath, lines=True) 
df.head()
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR7G5I41187FB4CE6C              NaN               NaN
#
#    artist_location artist_name             song_id            title  \
# 0  London, England    Adam Ant  SONHOTT12A8C13493C  Something Girls
#
#     duration  year
# 0  233.40363  1982

# %% [markdown]
# ## #1: `songs` Table
# 提取 `songs` 表的数据
# - 选择song ID, title, artist ID, year. and duration

# %%
song_data = df[["song_id", "title", "artist_id", "year", "duration"]].values[0].tolist()

# %%
songs_table_insert
# Out:
# '\nINSERT INTO songs (song_id, title, artist_id, year, duration)\nVALUES (%s, %s, %s, %s, %s) ON CONFLICT DO NOTHING;\n'

# %%
cur.execute(songs_table_insert, song_data)

# %%
conn.commit()

# %% [markdown]
# ## #2: `artists` Table
# 提取 `artists` 表的数据
# - 选择artist ID, name, location, latitude, and longtitude

# %%
artist_data = df[["artist_id", "artist_name", "artist_location", "artist_latitude", "artist_longitude"]].values[0].tolist()
artist_data
# Out:
# ['AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan]

# %%
cur.execute(artists_table_insert, artist_data)
conn.commit()

# %% [markdown]
# # 处理 `log_data`
# 对 `log_data` 进行ETL操作来创建 `time` and `users` 以及 `songplays` 表

# %%
log_files = get_files("data/log_data")

# %%
filepath = log_files[0]

# %%
df = pd.read_json(filepath, lines=True)
df.head(10)
# Out:
#                              artist        auth firstName gender  \
# 0                              None  Logged Out      None   None
# 1                              None   Logged In  Theodore      M
# 2                              None  Logged Out      None   None
# 3                              None  Logged Out      None   None
# 4                              None  Logged Out      None   None
# 5                              None   Logged In     Tegan      F
# 6  Facto Delafe y las flores azules   Logged In     Tegan      F
# 7                     Kings Of Leon   Logged In      Kate      F
# 8                   Franz Ferdinand   Logged In      Kate      F
# 9                      Blue October   Logged In     Tegan      F
#
#    itemInSession lastName     length level  \
# 0              0     None        NaN  free
# 1              1    Smith        NaN  free
# 2              0     None        NaN  paid
# 3              1     None        NaN  paid
# 4              2     None        NaN  paid
# 5              3   Levine        NaN  paid
# 6              4   Levine  315.81995  paid
# 7              0  Harrell  204.27710  paid
# 8              1  Harrell  204.12036  paid
# 9              5   Levine  272.32608  paid
#
#                                location method      page  registration  \
# 0                                  None    PUT     Login           NaN
# 1  Houston-The Woodlands-Sugar Land, TX    GET      Home  1.540306e+12
# 2                                  None    GET      Home           NaN
# 3                                  None    GET      Home           NaN
# 4                                  None    PUT     Login           NaN
# 5           Portland-South Portland, ME    GET      Home  1.540794e+12
# 6           Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 7              Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 8              Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 9           Portland-South Portland, ME    PUT  NextSong  1.540794e+12
#
#    sessionId                             song  status             ts  \
# 0        741                             None     307  1542760054796
# 1        741                             None     200  1542760086796
# 2        774                             None     200  1542761399796
# 3        774                             None     200  1542761485796
# 4        774                             None     307  1542761486796
# 5        774                             None     200  1542761784796
# 6        774                Enero en la playa     200  1542761878796
# 7        671                        Manhattan     200  1542761921796
# 8        671                          Michael     200  1542762125796
# 9        774  Drilled A Wire Through My Cheek     200  1542762193796
#
#                                            userAgent userId
# 0                                               None
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...     52
# 2                                               None
# 3                                               None
# 4                                               None
# 5  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 6  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 7  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 8  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 9  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80

# %% [markdown]
# ## #3: `time` Table
# - 筛选 `page`是`NextSong`的
# - 将 `ts` timestamp列转换为datetime
# - 提取出 `ts`列里的小时，day, week of year, month等等信息
# - 提取 `time`表需要的列，命名为 `column_labels`
# - 结合`column_labels`以及从`ts`提取到的数据，创建一个新的df, 命名为`time_df`

# %%
df = df.query("page == 'NextSong'")
df.head()
# Out:
#                               artist       auth firstName gender  \
# 6   Facto Delafe y las flores azules  Logged In     Tegan      F
# 7                      Kings Of Leon  Logged In      Kate      F
# 8                    Franz Ferdinand  Logged In      Kate      F
# 9                       Blue October  Logged In     Tegan      F
# 11                             Elisa  Logged In      Kate      F
#
#     itemInSession lastName     length level                     location  \
# 6               4   Levine  315.81995  paid  Portland-South Portland, ME
# 7               0  Harrell  204.27710  paid     Lansing-East Lansing, MI
# 8               1  Harrell  204.12036  paid     Lansing-East Lansing, MI
# 9               5   Levine  272.32608  paid  Portland-South Portland, ME
# 11              2  Harrell  248.97261  paid     Lansing-East Lansing, MI
#
#    method      page  registration  sessionId                             song  \
# 6     PUT  NextSong  1.540794e+12        774                Enero en la playa
# 7     PUT  NextSong  1.540473e+12        671                        Manhattan
# 8     PUT  NextSong  1.540473e+12        671                          Michael
# 9     PUT  NextSong  1.540794e+12        774  Drilled A Wire Through My Cheek
# 11    PUT  NextSong  1.540473e+12        671          Almeno Tu Nell'Universo
#
#     status             ts                                          userAgent  \
# 6      200  1542761878796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 7      200  1542761921796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 8      200  1542762125796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 9      200  1542762193796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 11     200  1542762329796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
#
#    userId
# 6      80
# 7      97
# 8      97
# 9      80
# 11     97

# %%
t = pd.to_datetime(df['ts'], unit='ms')
df['ts'] = pd.to_datetime(df['ts'], unit='ms')
df.head()
# Out:
#                               artist       auth firstName gender  \
# 6   Facto Delafe y las flores azules  Logged In     Tegan      F
# 7                      Kings Of Leon  Logged In      Kate      F
# 8                    Franz Ferdinand  Logged In      Kate      F
# 9                       Blue October  Logged In     Tegan      F
# 11                             Elisa  Logged In      Kate      F
#
#     itemInSession lastName     length level                     location  \
# 6               4   Levine  315.81995  paid  Portland-South Portland, ME
# 7               0  Harrell  204.27710  paid     Lansing-East Lansing, MI
# 8               1  Harrell  204.12036  paid     Lansing-East Lansing, MI
# 9               5   Levine  272.32608  paid  Portland-South Portland, ME
# 11              2  Harrell  248.97261  paid     Lansing-East Lansing, MI
#
#    method      page  registration  sessionId                             song  \
# 6     PUT  NextSong  1.540794e+12        774                Enero en la playa
# 7     PUT  NextSong  1.540473e+12        671                        Manhattan
# 8     PUT  NextSong  1.540473e+12        671                          Michael
# 9     PUT  NextSong  1.540794e+12        774  Drilled A Wire Through My Cheek
# 11    PUT  NextSong  1.540473e+12        671          Almeno Tu Nell'Universo
#
#     status                      ts  \
# 6      200 2018-11-21 00:57:58.796
# 7      200 2018-11-21 00:58:41.796
# 8      200 2018-11-21 01:02:05.796
# 9      200 2018-11-21 01:03:13.796
# 11     200 2018-11-21 01:05:29.796
#
#                                             userAgent userId
# 6   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 7   "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 8   "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 9   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 11  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97

# %%
time_data = list((t, t.dt.hour, t.dt.day, t.dt.weekofyear, t.dt.month, t.dt.year, t.dt.weekday))
column_labels = list(('start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday'))
# Out:
# /home/sunxichen/anaconda3/envs/Data_Engineering/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """Entry point for launching an IPython kernel.

# %%
time_data[0]
# Out:
# 6     2018-11-21 00:57:58.796
# 7     2018-11-21 00:58:41.796
# 8     2018-11-21 01:02:05.796
# 9     2018-11-21 01:03:13.796
# 11    2018-11-21 01:05:29.796
#                 ...
# 512   2018-11-21 23:47:05.796
# 513   2018-11-21 23:50:02.796
# 514   2018-11-21 23:51:48.796
# 515   2018-11-21 23:53:48.796
# 516   2018-11-21 23:57:45.796
# Name: ts, Length: 437, dtype: datetime64[ns]

# %%
time_df =  pd.DataFrame.from_dict(dict(zip(column_labels, time_data)))
time_df.head()
# Out:
#                 start_time  hour  day  week  month  year  weekday
# 6  2018-11-21 00:57:58.796     0   21    47     11  2018        2
# 7  2018-11-21 00:58:41.796     0   21    47     11  2018        2
# 8  2018-11-21 01:02:05.796     1   21    47     11  2018        2
# 9  2018-11-21 01:03:13.796     1   21    47     11  2018        2
# 11 2018-11-21 01:05:29.796     1   21    47     11  2018        2

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# ## #4 `users`表
# - 选出 user ID, first ID, first name, last name, gender以及level列

# %%
user_df = df[["userId", "firstName", "lastName", "gender", "level"]]

# %%
for i, row in user_df.iterrows():
    cur.execute(users_table_insert, row)
    conn.commit()

# %% [markdown]
# ## #5: `songplays` 表
# - 首先要根据 `song` `artist` `length` 从 `songs`表和`artists`表中选取 songid和artistid
# - 入表

# %%
for index, row in df.iterrows():
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None
        
    # insert songplay record
    songplay_data = (index, row.ts, row.userId, row.level, songid, artistid, row.sessionId,\
                     row.location, row.userAgent)
    cur.execute(songplays_table_insert, songplay_data)
    conn.commit()

# %%
conn.close()
